# %%
# Import bibliothèques et modules 
import pandas as pd
import numpy as np
import sqlite3
from datetime import datetime, timedelta

import data_collector 
import base_builder
import strategy     
import performances
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  24 of 24 completed
# Table clients créée avec succès.
# Table produits créée avec succès.
# Table portfolios créée avec succès.
# Table managers créée avec succès.
# Table deals créée avec succès.
# Erreur SQLite : table Returns already exists
# Morris clients insérés avec succès dans la table 'Clients'.
# Zamora clients insérés avec succès dans la table 'Clients'.
# Williams clients insérés avec succès dans la table 'Clients'.
# Erreur SQLite : UNIQUE constraint failed: Products.ticker
# Erreur SQLite : UNIQUE constraint failed: Products.ticker
# Erreur SQLite : UNIQUE constraint failed: Products.ticker
# Erreur SQLite : UNIQUE constraint failed: Products.ticker
# Erreur SQLite : UNIQUE constraint failed: Products.ticker
# Erreur SQLite : UNIQUE constraint failed: Products.ticker
# Erreur SQLite : UNIQUE constraint failed: Products.ticker
# ...

# %%
# Création et peuplement de la base de données
base_builder.main()
# Out:
# [*********************100%***********************]  24 of 24 completed
# Table clients créée avec succès.
# Table produits créée avec succès.
# Table portfolios créée avec succès.
# Table managers créée avec succès.
# Table deals créée avec succès.
# Erreur SQLite : table Returns already exists
# Conway clients insérés avec succès dans la table 'Clients'.
# Johnson clients insérés avec succès dans la table 'Clients'.
# Espinoza clients insérés avec succès dans la table 'Clients'.
# Erreur SQLite : UNIQUE constraint failed: Products.ticker
# Erreur SQLite : UNIQUE constraint failed: Products.ticker
# Erreur SQLite : UNIQUE constraint failed: Products.ticker
# Erreur SQLite : UNIQUE constraint failed: Products.ticker
# Erreur SQLite : UNIQUE constraint failed: Products.ticker
# Erreur SQLite : UNIQUE constraint failed: Products.ticker
# Erreur SQLite : UNIQUE constraint failed: Products.ticker
# Erreur SQLite : UNIQUE constraint failed: Products.ticker
# ...

# %%
# Lancement de la stratégie 
strategy.run_weekly_updates()
# Out:
# Vente exécutée pour ETF Amundi MSCI World dans le portefeuille 1 le 2023-01-02
# Portefeuille 2 a déjà atteint 2 jours de deals en 1/2023.
# Vente exécutée pour Amazon dans le portefeuille 3 le 2023-01-02
# Vente exécutée pour Microsoft Corporation dans le portefeuille 3 le 2023-01-02
# Vente exécutée pour Total Energies dans le portefeuille 3 le 2023-01-02
# Vente exécutée pour Novo Nordisk dans le portefeuille 3 le 2023-01-02
# Vente exécutée pour ETF Amundi MSCI World dans le portefeuille 4 le 2023-01-02
# Portefeuille 5 a déjà atteint 2 jours de deals en 1/2023.
# Vente exécutée pour Amazon dans le portefeuille 6 le 2023-01-02
# Vente exécutée pour Microsoft Corporation dans le portefeuille 6 le 2023-01-02
# Vente exécutée pour Total Energies dans le portefeuille 6 le 2023-01-02
# Vente exécutée pour Novo Nordisk dans le portefeuille 6 le 2023-01-02
# Portefeuille 2 a déjà atteint 2 jours de deals en 1/2023.
# ...

# %%
# Lancement de l'évaluation de performance
performances.main()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Connexion à la base de données réussie.
#
# === Contenu de tous les portefeuilles ===
# Portefeuille Portfolio_low_risk contient : ['ETF Amundi Physical Gold', 'ETF Amundi MSCI World', 'ETF iShares French Gov bonds', 'ETF iSHares Germany Gov', 'ETF iShares Chinese Gov', 'ETF iShares US Gov Bonds']
# Portefeuille Portfolio_low_turnover contient : ['ETF Amundi Corporate Bonds', 'ETF Amundi S&P 500', 'ETF iShares Private Equity', 'ETF iShares Dev Markets Property Yield', 'ETF MSCI World Healthcare']
# Portefeuille Portfolio_high_yield_equity_only contient : ['Apple', 'Amazon', 'Microsoft Corporation', 'Google', 'Tesla', 'Meta', 'NVDIA', 'Thales', 'Airbus', 'Total Energies', 'LVMH', 'Hermes', 'Novo Nordisk']
#
# === Derniers deals par portefeuille ===
#
# Portefeuille Portfolio_low_risk :
#       date        wallet_name             product_name  qty operation
# ...
